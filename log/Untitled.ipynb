# %%
import numpy as np
analise = np.load('familia4.npz', allow_pickle=True)

print(analise['images'])
# Out:
# [{'Arquivo': 'C:/Users/milal/Downloads/batch_download/family playing - Google Search\\2Q__ (1).jpg', 'data': (0, 0, None, None, 0.98773885, None, None, [], []), 'Tempo de Análise': 0.694147}
#  {'Arquivo': 'C:/Users/milal/Downloads/batch_download/family playing - Google Search\\2Q__ (2).jpg', 'data': (0, 0, None, None, 0.6360369, None, None, [], []), 'Tempo de Análise': 0.132641}
#  {'Arquivo': 'C:/Users/milal/Downloads/batch_download/family playing - Google Search\\2Q__ (4).jpg', 'data': (0, 0, None, None, 0.986, None, None, [], []), 'Tempo de Análise': 0.133647}
#  {'Arquivo': 'C:/Users/milal/Downloads/batch_download/family playing - Google Search\\2Q__ (5).jpg', 'data': (0, 0, None, None, 0.9646438, None, None, [], []), 'Tempo de Análise': 0.10871}
#  {'Arquivo': 'C:/Users/milal/Downloads/batch_download/family playing - Google Search\\2Q__ (6).jpg', 'data': (0, 0, None, None, 0.9930058, None, None, [], []), 'Tempo de Análise': 0.138628}
# ...
