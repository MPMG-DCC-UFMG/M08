# %%
import numpy as np

log = np.load('teste_video.npz', allow_pickle=True)

# %%
log['videos']
# Out:
# array([{'Arquivo': './batch_download/family playing/Belle_Delphine_se_masturbando_pro_Only_Fans[Pornhub Downloader].mp4', 'frames_video': {12: (0, 0, None, None, 0.97583836, None, None, [], []), 22: (0, 0, None, None, 0.929125, None, None, [], []), 90: (0, 0, None, None, 0.7506347, None, None, [], []), 122: (0, 0, None, None, 0.80099946, None, None, [], []), 168: (0, 0, None, None, 0.8756947, None, None, [], []), 203: (0, 0, None, None, 0.9038113, None, None, [], []), 211: (0, 0, None, None, 0.91097325, None, None, [], []), 212: (0, 0, None, None, 0.9010681, None, None, [], []), 246: (0, 0, None, None, 0.75774676, None, None, [], []), 265: (0, 0, None, None, 0.8855689, None, None, [], []), 324: (0, 0, None, None, 0.95063764, None, None, [], []), 402: (0, 0, None, None, 0.7475033, None, None, [], []), 443: (0, 0, None, None, 0.6763136, None, None, [], []), 445: (0, 0, None, None, 0.65655804, None, None, [], []), 480: (0, 0, None, None, 0.5613657, None, None, [], []), 558: (0, 0, None,
# ...
